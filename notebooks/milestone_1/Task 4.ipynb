# %% [markdown]
# # Task 4 - Tidy Data
#
# For this task we want to tidy the raw JSON data we fetched from the NHL API. All we need to tidy the data into a clean DataFrame ready to be used for analysis is an instance of the `NHLDataParser` class.

# %%
from ift6758.data.nhl_data_parser import NHLDataParser

# %% [markdown]
# The `NHLDataParser` class has its own instance of the `NHLDataFetcher` class. If the game isn't found locally on the machine, it will fetch it and then tidy it. Here's a sample of using a specific game ID.

# %%
data_parser = NHLDataParser()
df = data_parser.get_shot_and_goal_pbp_df('2016020033')
df.sample(10) # displays 10 random shot/goal events
# Out:
#          gameId  timeRemaining  periodNumber timeInPeriod  isGoal  shotType  \
# 293  2016020033             96             3        18:24       1     wrist
# 214  2016020033           1077             3        02:03       0     wrist
# 212  2016020033           1111             3        01:29       0     wrist
# 95   2016020033           1109             2        01:31       0      slap
# 67   2016020033            198             1        16:42       0      slap
# 105  2016020033           1038             2        02:42       0  backhand
# 19   2016020033            904             1        04:56       0     wrist
# 275  2016020033            280             3        15:20       0      snap
# 42   2016020033            520             1        11:20       0     wrist
# 15   2016020033            968             1        03:52       0     wrist
#
#      emptyNet  xCoord  yCoord zoneCode  ...   shootingPlayer   goalieInNet  \
# 293         1     4.0     7.0        N  ...  Mats Zuccarello           NaN
# 214         0    38.0   -19.0        O  ...   David Schlemko  Antti Raanta
# 212         0   -40.0   -34.0        O  ...      Kevin Hayes  Martin Jones
# 95          0   -46.0     0.0        O  ...       Matt Nieto  Antti Raanta
# 67          0    41.0   -35.0        O  ...      Brent Burns  Antti Raanta
# 105         0    81.0    -6.0        O  ...     Derek Stepan  Martin Jones
# 19          0   -85.0   -18.0        O  ...    Ryan McDonagh  Martin Jones
# 275         0    80.0    -5.0        O  ...    Logan Couture  Antti Raanta
# 42          0   -65.0   -20.0        O  ...    Chris Kreider  Martin Jones
# 15          0    53.0    33.0        O  ...    Logan Couture  Antti Raanta
#
#     previousEvent  timeDiff previousEventX previousEventY rebound  \
# 293           hit       6.0          -66.0          -25.0       0
# 214       faceoff      33.0          -68.0          -21.0       0
# 212      stoppage      -1.0            NaN            NaN       0
# 95            hit       8.0           98.0          -28.0       0
# 67            hit      34.0           95.0           34.0       0
# 105      giveaway       2.0           96.0           -3.0       0
# 19   blocked-shot      45.0           69.0           11.0       0
# 275   missed-shot       7.0           71.0           16.0       0
# 42            hit      46.0           -4.0           32.0       0
# 15   shot-on-goal      28.0          -79.0            4.0       1
#
#      distanceDiff  shotAngleDiff      speed
# 293     76.967526       0.000000  12.827921
# 214    106.018866       0.000000   3.212693
# 212           NaN       0.000000   6.105804
# 95     146.696967       0.000000  18.337121
# 67      87.618491       0.000000   2.577014
# 105     15.297059       0.000000   7.648529
# 19     156.706732       0.000000   3.482372
# 275     22.847319       0.000000   3.263903
# 42      80.156098       0.000000   1.742524
# 15     135.148067      20.709038   4.826717
#
# [10 rows x 24 columns]

# %% [markdown]
# We can also use the `NHLDataParser` to get tidied shot and goal play-by-play for an entire season.

# %%
df = data_parser.get_shot_and_goal_pbp_df_for_season(2016)
df.sample(10)
# Out:
# Fetching regular season games for 2016...
# Processing game_id: 2016020001
# Processing game_id: 2016020002
# Processing game_id: 2016020003
# Processing game_id: 2016020004
# Processing game_id: 2016020005
# Processing game_id: 2016020006
# Processing game_id: 2016020007
# Processing game_id: 2016020008
# Processing game_id: 2016020009
# Processing game_id: 2016020010
# Processing game_id: 2016020011
# Processing game_id: 2016020012
# Processing game_id: 2016020013
# Processing game_id: 2016020014
# Processing game_id: 2016020015
# Processing game_id: 2016020016
# Processing game_id: 2016020017
# Processing game_id: 2016020018
# Processing game_id: 2016020019
# Processing game_id: 2016020020
# Processing game_id: 2016020021
# Processing game_id: 2016020022
# Processing game_id: 2016020023
# Processing game_id: 2016020024
# Processing game_id: 2016020025
# Processing game_id: 2016020026
# Processing game_id: 2016020027
# Processing game_id: 2016020028
# Processing game_id: 2016020029
# Processing game_id: 2016020030
# Processing game_id: 2016020031
# Processing game_id: 2016020032
# Processing game_id: 2016020033
# Processing game_id: 2016020034
# Processing game_id: 2016020035
# Processing game_id: 2016020036
# Processing game_id: 2016020037
# Processing game_id: 2016020038
# Processing game_id: 2016020039
# Processing game_id: 2016020040
# Processing game_id: 2016020041
# Processing game_id: 2016020042
# Processing game_id: 2016020043
# Processing game_id: 2016020044
# Processing game_id: 2016020045
# Processing game_id: 2016020046
# Processing game_id: 2016020047
# Processing game_id: 2016020048
# Processing game_id: 2016020049
# Processing game_id: 2016020050
# Processing game_id: 2016020051
# Processing game_id: 2016020052
# Processing game_id: 2016020053
# Processing game_id: 2016020054
# Processing game_id: 2016020055
# Processing game_id: 2016020056
# Processing game_id: 2016020057
# Processing game_id: 2016020058
# Processing game_id: 2016020059
# Processing game_id: 2016020060
# Processing game_id: 2016020061
# Processing game_id: 2016020062
# Processing game_id: 2016020063
# Processing game_id: 2016020064
# Processing game_id: 2016020065
# Processing game_id: 2016020066
# Processing game_id: 2016020067
# Processing game_id: 2016020068
# Processing game_id: 2016020069
# Processing game_id: 2016020070
# Processing game_id: 2016020071
# Processing game_id: 2016020072
# Processing game_id: 2016020073
# Processing game_id: 2016020074
# Processing game_id: 2016020075
# Processing game_id: 2016020076
# Processing game_id: 2016020077
# Processing game_id: 2016020078
# Processing game_id: 2016020079
# Processing game_id: 2016020080
# Processing game_id: 2016020081
# Processing game_id: 2016020082
# Processing game_id: 2016020083
# Processing game_id: 2016020084
# Processing game_id: 2016020085
# Processing game_id: 2016020086
# Processing game_id: 2016020087
# Processing game_id: 2016020088
# Processing game_id: 2016020089
# Processing game_id: 2016020090
# Processing game_id: 2016020091
# Processing game_id: 2016020092
# Processing game_id: 2016020093
# Processing game_id: 2016020094
# Processing game_id: 2016020095
# Processing game_id: 2016020096
# Processing game_id: 2016020097
# Processing game_id: 2016020098
# Processing game_id: 2016020099
# Processing game_id: 2016020100
# Processing game_id: 2016020101
# Processing game_id: 2016020102
# Processing game_id: 2016020103
# Processing game_id: 2016020104
# Processing game_id: 2016020105
# Processing game_id: 2016020106
# Processing game_id: 2016020107
# Processing game_id: 2016020108
# Processing game_id: 2016020109
# Processing game_id: 2016020110
# Processing game_id: 2016020111
# Processing game_id: 2016020112
# Processing game_id: 2016020113
# Processing game_id: 2016020114
# Processing game_id: 2016020115
# Processing game_id: 2016020116
# Processing game_id: 2016020117
# Processing game_id: 2016020118
# Processing game_id: 2016020119
# Processing game_id: 2016020120
# Processing game_id: 2016020121
# Processing game_id: 2016020122
# Processing game_id: 2016020123
# Processing game_id: 2016020124
# Processing game_id: 2016020125
# Processing game_id: 2016020126
# Processing game_id: 2016020127
# Processing game_id: 2016020128
# Processing game_id: 2016020129
# Processing game_id: 2016020130
# Processing game_id: 2016020131
# Processing game_id: 2016020132
# Processing game_id: 2016020133
# Processing game_id: 2016020134
# Processing game_id: 2016020135
# Processing game_id: 2016020136
# Processing game_id: 2016020137
# Processing game_id: 2016020138
# Processing game_id: 2016020139
# Processing game_id: 2016020140
# Processing game_id: 2016020141
# Processing game_id: 2016020142
# Processing game_id: 2016020143
# Processing game_id: 2016020144
# Processing game_id: 2016020145
# Processing game_id: 2016020146
# Processing game_id: 2016020147
# Processing game_id: 2016020148
# Processing game_id: 2016020149
# Processing game_id: 2016020150
# Processing game_id: 2016020151
# Processing game_id: 2016020152
# Processing game_id: 2016020153
# Processing game_id: 2016020154
# Processing game_id: 2016020155
# Processing game_id: 2016020156
# Processing game_id: 2016020157
# Processing game_id: 2016020158
# Processing game_id: 2016020159
# Processing game_id: 2016020160
# Processing game_id: 2016020161
# Processing game_id: 2016020162
# Processing game_id: 2016020163
# Processing game_id: 2016020164
# Processing game_id: 2016020165
# Processing game_id: 2016020166
# Processing game_id: 2016020167
# Processing game_id: 2016020168
# Processing game_id: 2016020169
# Processing game_id: 2016020170
# Processing game_id: 2016020171
# Processing game_id: 2016020172
# Processing game_id: 2016020173
# Processing game_id: 2016020174
# Processing game_id: 2016020175
# Processing game_id: 2016020176
# Processing game_id: 2016020177
# Processing game_id: 2016020178
# Processing game_id: 2016020179
# Processing game_id: 2016020180
# Processing game_id: 2016020181
# Processing game_id: 2016020182
# Processing game_id: 2016020183
# Processing game_id: 2016020184
# Processing game_id: 2016020185
# Processing game_id: 2016020186
# Processing game_id: 2016020187
# Processing game_id: 2016020188
# Processing game_id: 2016020189
# Processing game_id: 2016020190
# Processing game_id: 2016020191
# Processing game_id: 2016020192
# Processing game_id: 2016020193
# Processing game_id: 2016020194
# Processing game_id: 2016020195
# Processing game_id: 2016020196
# Processing game_id: 2016020197
# Processing game_id: 2016020198
# Processing game_id: 2016020199
# Processing game_id: 2016020200
# Processing game_id: 2016020201
# Processing game_id: 2016020202
# Processing game_id: 2016020203
# Processing game_id: 2016020204
# Processing game_id: 2016020205
# Processing game_id: 2016020206
# Processing game_id: 2016020207
# Processing game_id: 2016020208
# Processing game_id: 2016020209
# Processing game_id: 2016020210
# Processing game_id: 2016020211
# Processing game_id: 2016020212
# Processing game_id: 2016020213
# Processing game_id: 2016020214
# Processing game_id: 2016020215
# Processing game_id: 2016020216
# Processing game_id: 2016020217
# Processing game_id: 2016020218
# Processing game_id: 2016020219
# Processing game_id: 2016020220
# Processing game_id: 2016020221
# Processing game_id: 2016020222
# Processing game_id: 2016020223
# Processing game_id: 2016020224
# Processing game_id: 2016020225
# Processing game_id: 2016020226
# Processing game_id: 2016020227
# Processing game_id: 2016020228
# Processing game_id: 2016020229
# Processing game_id: 2016020230
# Processing game_id: 2016020231
# Processing game_id: 2016020232
# Processing game_id: 2016020233
# Processing game_id: 2016020234
# Processing game_id: 2016020235
# Processing game_id: 2016020236
# Processing game_id: 2016020237
# Processing game_id: 2016020238
# Processing game_id: 2016020239
# Processing game_id: 2016020240
# Processing game_id: 2016020241
# Processing game_id: 2016020242
# Processing game_id: 2016020243
# Processing game_id: 2016020244
# Processing game_id: 2016020245
# Processing game_id: 2016020246
# Processing game_id: 2016020247
# Processing game_id: 2016020248
# Processing game_id: 2016020249
# Processing game_id: 2016020250
# Processing game_id: 2016020251
# Processing game_id: 2016020252
# Processing game_id: 2016020253
# Processing game_id: 2016020254
# Processing game_id: 2016020255
# Processing game_id: 2016020256
# Processing game_id: 2016020257
# Processing game_id: 2016020258
# Processing game_id: 2016020259
# Processing game_id: 2016020260
# Processing game_id: 2016020261
# Processing game_id: 2016020262
# Processing game_id: 2016020263
# Processing game_id: 2016020264
# Processing game_id: 2016020265
# Processing game_id: 2016020266
# Processing game_id: 2016020267
# Processing game_id: 2016020268
# Processing game_id: 2016020269
# Processing game_id: 2016020270
# Processing game_id: 2016020271
# Processing game_id: 2016020272
# Processing game_id: 2016020273
# Processing game_id: 2016020274
# Processing game_id: 2016020275
# Processing game_id: 2016020276
# Processing game_id: 2016020277
# Processing game_id: 2016020278
# Processing game_id: 2016020279
# Processing game_id: 2016020280
# Processing game_id: 2016020281
# Processing game_id: 2016020282
# Processing game_id: 2016020283
# Processing game_id: 2016020284
# Processing game_id: 2016020285
# Processing game_id: 2016020286
# Processing game_id: 2016020287
# Processing game_id: 2016020288
# Processing game_id: 2016020289
# Processing game_id: 2016020290
# Processing game_id: 2016020291
# Processing game_id: 2016020292
# Processing game_id: 2016020293
# Processing game_id: 2016020294
# Processing game_id: 2016020295
# Processing game_id: 2016020296
# Processing game_id: 2016020297
# Processing game_id: 2016020298
# Processing game_id: 2016020299
# Processing game_id: 2016020300
# Processing game_id: 2016020301
# Processing game_id: 2016020302
# Processing game_id: 2016020303
# Processing game_id: 2016020304
# Processing game_id: 2016020305
# Processing game_id: 2016020306
# Processing game_id: 2016020307
# Processing game_id: 2016020308
# Processing game_id: 2016020309
# Processing game_id: 2016020310
# Processing game_id: 2016020311
# Processing game_id: 2016020312
# Processing game_id: 2016020313
# Processing game_id: 2016020314
# Processing game_id: 2016020315
# Processing game_id: 2016020316
# Processing game_id: 2016020317
# Processing game_id: 2016020318
# Processing game_id: 2016020319
# Processing game_id: 2016020320
# Processing game_id: 2016020321
# Processing game_id: 2016020322
# Processing game_id: 2016020323
# Processing game_id: 2016020324
# Processing game_id: 2016020325
# Processing game_id: 2016020326
# Processing game_id: 2016020327
# Processing game_id: 2016020328
# Processing game_id: 2016020329
# Processing game_id: 2016020330
# Processing game_id: 2016020331
# Processing game_id: 2016020332
# Processing game_id: 2016020333
# Processing game_id: 2016020334
# Processing game_id: 2016020335
# Processing game_id: 2016020336
# Processing game_id: 2016020337
# Processing game_id: 2016020338
# Processing game_id: 2016020339
# Processing game_id: 2016020340
# Processing game_id: 2016020341
# Processing game_id: 2016020342
# Processing game_id: 2016020343
# Processing game_id: 2016020344
# Processing game_id: 2016020345
# Processing game_id: 2016020346
# Processing game_id: 2016020347
# Processing game_id: 2016020348
# Processing game_id: 2016020349
# Processing game_id: 2016020350
# Processing game_id: 2016020351
# Processing game_id: 2016020352
# Processing game_id: 2016020353
# Processing game_id: 2016020354
# Processing game_id: 2016020355
# Processing game_id: 2016020356
# Processing game_id: 2016020357
# Processing game_id: 2016020358
# Processing game_id: 2016020359
# Processing game_id: 2016020360
# Processing game_id: 2016020361
# Processing game_id: 2016020362
# Processing game_id: 2016020363
# Processing game_id: 2016020364
# Processing game_id: 2016020365
# Processing game_id: 2016020366
# Processing game_id: 2016020367
# Processing game_id: 2016020368
# Processing game_id: 2016020369
# Processing game_id: 2016020370
# Processing game_id: 2016020371
# Processing game_id: 2016020372
# Processing game_id: 2016020373
# Processing game_id: 2016020374
# Processing game_id: 2016020375
# Processing game_id: 2016020376
# Processing game_id: 2016020377
# Processing game_id: 2016020378
# Processing game_id: 2016020379
# Processing game_id: 2016020380
# Processing game_id: 2016020381
# Processing game_id: 2016020382
# Processing game_id: 2016020383
# Processing game_id: 2016020384
# Processing game_id: 2016020385
# Processing game_id: 2016020386
# Processing game_id: 2016020387
# Processing game_id: 2016020388
# Processing game_id: 2016020389
# Processing game_id: 2016020390
# Processing game_id: 2016020391
# Processing game_id: 2016020392
# Processing game_id: 2016020393
# Processing game_id: 2016020394
# Processing game_id: 2016020395
# Processing game_id: 2016020396
# Processing game_id: 2016020397
# Processing game_id: 2016020398
# Processing game_id: 2016020399
# Processing game_id: 2016020400
# Processing game_id: 2016020401
# Processing game_id: 2016020402
# Processing game_id: 2016020403
# Processing game_id: 2016020404
# Processing game_id: 2016020405
# Processing game_id: 2016020406
# Processing game_id: 2016020407
# Processing game_id: 2016020408
# Processing game_id: 2016020409
# Processing game_id: 2016020410
# Processing game_id: 2016020411
# Processing game_id: 2016020412
# Processing game_id: 2016020413
# Processing game_id: 2016020414
# Processing game_id: 2016020415
# Processing game_id: 2016020416
# Processing game_id: 2016020417
# Processing game_id: 2016020418
# Processing game_id: 2016020419
# Processing game_id: 2016020420
# Processing game_id: 2016020421
# Processing game_id: 2016020422
# Processing game_id: 2016020423
# Processing game_id: 2016020424
# Processing game_id: 2016020425
# Processing game_id: 2016020426
# Processing game_id: 2016020427
# Processing game_id: 2016020428
# Processing game_id: 2016020429
# Processing game_id: 2016020430
# Processing game_id: 2016020431
# Processing game_id: 2016020432
# Processing game_id: 2016020433
# Processing game_id: 2016020434
# Processing game_id: 2016020435
# Processing game_id: 2016020436
# Processing game_id: 2016020437
# Processing game_id: 2016020438
# Processing game_id: 2016020439
# Processing game_id: 2016020440
# Processing game_id: 2016020441
# Processing game_id: 2016020442
# Processing game_id: 2016020443
# Processing game_id: 2016020444
# Processing game_id: 2016020445
# Processing game_id: 2016020446
# Processing game_id: 2016020447
# Processing game_id: 2016020448
# Processing game_id: 2016020449
# Processing game_id: 2016020450
# Processing game_id: 2016020451
# Processing game_id: 2016020452
# Processing game_id: 2016020453
# Processing game_id: 2016020454
# Processing game_id: 2016020455
# Processing game_id: 2016020456
# Processing game_id: 2016020457
# Processing game_id: 2016020458
# Processing game_id: 2016020459
# Processing game_id: 2016020460
# Processing game_id: 2016020461
# Processing game_id: 2016020462
# Processing game_id: 2016020463
# Processing game_id: 2016020464
# Processing game_id: 2016020465
# Processing game_id: 2016020466
# Processing game_id: 2016020467
# Processing game_id: 2016020468
# Processing game_id: 2016020469
# Processing game_id: 2016020470
# Processing game_id: 2016020471
# Processing game_id: 2016020472
# Processing game_id: 2016020473
# Processing game_id: 2016020474
# Processing game_id: 2016020475
# Processing game_id: 2016020476
# Processing game_id: 2016020477
# Processing game_id: 2016020478
# Processing game_id: 2016020479
# Processing game_id: 2016020480
# Processing game_id: 2016020481
# Processing game_id: 2016020482
# Processing game_id: 2016020483
# Processing game_id: 2016020484
# Processing game_id: 2016020485
# Processing game_id: 2016020486
# Processing game_id: 2016020487
# Processing game_id: 2016020488
# Processing game_id: 2016020489
# Processing game_id: 2016020490
# Processing game_id: 2016020491
# Processing game_id: 2016020492
# Processing game_id: 2016020493
# Processing game_id: 2016020494
# Processing game_id: 2016020495
# Processing game_id: 2016020496
# Processing game_id: 2016020497
# Processing game_id: 2016020498
# Processing game_id: 2016020499
# Processing game_id: 2016020500
# Processing game_id: 2016020501
# Processing game_id: 2016020502
# Processing game_id: 2016020503
# Processing game_id: 2016020504
# Processing game_id: 2016020505
# Processing game_id: 2016020506
# Processing game_id: 2016020507
# Processing game_id: 2016020508
# Processing game_id: 2016020509
# Processing game_id: 2016020510
# Processing game_id: 2016020511
# Processing game_id: 2016020512
# Processing game_id: 2016020513
# Processing game_id: 2016020514
# Processing game_id: 2016020515
# Processing game_id: 2016020516
# Processing game_id: 2016020517
# Processing game_id: 2016020518
# Processing game_id: 2016020519
# Processing game_id: 2016020520
# Processing game_id: 2016020521
# Processing game_id: 2016020522
# Processing game_id: 2016020523
# Processing game_id: 2016020524
# Processing game_id: 2016020525
# Processing game_id: 2016020526
# Processing game_id: 2016020527
# Processing game_id: 2016020528
# Processing game_id: 2016020529
# Processing game_id: 2016020530
# Processing game_id: 2016020531
# Processing game_id: 2016020532
# Processing game_id: 2016020533
# Processing game_id: 2016020534
# Processing game_id: 2016020535
# Processing game_id: 2016020536
# Processing game_id: 2016020537
# Processing game_id: 2016020538
# Processing game_id: 2016020539
# Processing game_id: 2016020540
# Processing game_id: 2016020541
# Processing game_id: 2016020542
# Processing game_id: 2016020543
# Processing game_id: 2016020544
# Processing game_id: 2016020545
# Processing game_id: 2016020546
# Processing game_id: 2016020547
# Processing game_id: 2016020548
# Processing game_id: 2016020549
# Processing game_id: 2016020550
# Processing game_id: 2016020551
# Processing game_id: 2016020552
# Processing game_id: 2016020553
# Processing game_id: 2016020554
# Processing game_id: 2016020555
# Processing game_id: 2016020556
# Processing game_id: 2016020557
# Processing game_id: 2016020558
# Processing game_id: 2016020559
# Processing game_id: 2016020560
# Processing game_id: 2016020561
# Processing game_id: 2016020562
# Processing game_id: 2016020563
# Processing game_id: 2016020564
# Processing game_id: 2016020565
# Processing game_id: 2016020566
# Processing game_id: 2016020567
# Processing game_id: 2016020568
# Processing game_id: 2016020569
# Processing game_id: 2016020570
# Processing game_id: 2016020571
# Processing game_id: 2016020572
# Processing game_id: 2016020573
# Processing game_id: 2016020574
# Processing game_id: 2016020575
# Processing game_id: 2016020576
# Processing game_id: 2016020577
# Processing game_id: 2016020578
# Processing game_id: 2016020579
# Processing game_id: 2016020580
# Processing game_id: 2016020581
# Processing game_id: 2016020582
# Processing game_id: 2016020583
# Processing game_id: 2016020584
# Processing game_id: 2016020585
# Processing game_id: 2016020586
# Processing game_id: 2016020587
# Processing game_id: 2016020588
# Processing game_id: 2016020589
# Processing game_id: 2016020590
# Processing game_id: 2016020591
# Processing game_id: 2016020592
# Processing game_id: 2016020593
# Processing game_id: 2016020594
# Processing game_id: 2016020595
# Processing game_id: 2016020596
# Processing game_id: 2016020597
# Processing game_id: 2016020598
# Processing game_id: 2016020599
# Processing game_id: 2016020600
# Processing game_id: 2016020601
# Processing game_id: 2016020602
# Processing game_id: 2016020603
# Processing game_id: 2016020604
# Processing game_id: 2016020605
# Processing game_id: 2016020606
# Processing game_id: 2016020607
# Processing game_id: 2016020608
# Processing game_id: 2016020609
# Processing game_id: 2016020610
# Processing game_id: 2016020611
# Processing game_id: 2016020612
# Processing game_id: 2016020613
# Processing game_id: 2016020614
# Processing game_id: 2016020615
# Processing game_id: 2016020616
# Processing game_id: 2016020617
# Processing game_id: 2016020618
# Processing game_id: 2016020619
# Processing game_id: 2016020620
# Processing game_id: 2016020621
# Processing game_id: 2016020622
# Processing game_id: 2016020623
# Processing game_id: 2016020624
# Processing game_id: 2016020625
# Processing game_id: 2016020626
# Processing game_id: 2016020627
# Processing game_id: 2016020628
# Processing game_id: 2016020629
# Processing game_id: 2016020630
# Processing game_id: 2016020631
# Processing game_id: 2016020632
# Processing game_id: 2016020633
# Processing game_id: 2016020634
# Processing game_id: 2016020635
# Processing game_id: 2016020636
# Processing game_id: 2016020637
# Processing game_id: 2016020638
# Processing game_id: 2016020639
# Processing game_id: 2016020640
# Processing game_id: 2016020641
# Processing game_id: 2016020642
# Processing game_id: 2016020643
# Processing game_id: 2016020644
# Processing game_id: 2016020645
# Processing game_id: 2016020646
# Processing game_id: 2016020647
# Processing game_id: 2016020648
# Processing game_id: 2016020649
# Processing game_id: 2016020650
# Processing game_id: 2016020651
# Processing game_id: 2016020652
# Processing game_id: 2016020653
# Processing game_id: 2016020654
# Processing game_id: 2016020655
# Processing game_id: 2016020656
# Processing game_id: 2016020657
# Processing game_id: 2016020658
# Processing game_id: 2016020659
# Processing game_id: 2016020660
# Processing game_id: 2016020661
# Processing game_id: 2016020662
# Processing game_id: 2016020663
# Processing game_id: 2016020664
# Processing game_id: 2016020665
# Processing game_id: 2016020666
# Processing game_id: 2016020667
# Processing game_id: 2016020668
# Processing game_id: 2016020669
# Processing game_id: 2016020670
# Processing game_id: 2016020671
# Processing game_id: 2016020672
# Processing game_id: 2016020673
# Processing game_id: 2016020674
# Processing game_id: 2016020675
# Processing game_id: 2016020676
# Processing game_id: 2016020677
# Processing game_id: 2016020678
# Processing game_id: 2016020679
# Processing game_id: 2016020680
# Processing game_id: 2016020681
# Processing game_id: 2016020682
# Processing game_id: 2016020683
# Processing game_id: 2016020684
# Processing game_id: 2016020685
# Processing game_id: 2016020686
# Processing game_id: 2016020687
# Processing game_id: 2016020688
# Processing game_id: 2016020689
# Processing game_id: 2016020690
# Processing game_id: 2016020691
# Processing game_id: 2016020692
# Processing game_id: 2016020693
# Processing game_id: 2016020694
# Processing game_id: 2016020695
# Processing game_id: 2016020696
# Processing game_id: 2016020697
# Processing game_id: 2016020698
# Processing game_id: 2016020699
# Processing game_id: 2016020700
# Processing game_id: 2016020701
# Processing game_id: 2016020702
# Processing game_id: 2016020703
# Processing game_id: 2016020704
# Processing game_id: 2016020705
# Processing game_id: 2016020706
# Processing game_id: 2016020707
# Processing game_id: 2016020708
# Processing game_id: 2016020709
# Processing game_id: 2016020710
# Processing game_id: 2016020711
# Processing game_id: 2016020712
# Processing game_id: 2016020713
# Processing game_id: 2016020714
# Processing game_id: 2016020715
# Processing game_id: 2016020716
# Processing game_id: 2016020717
# Processing game_id: 2016020718
# Processing game_id: 2016020719
# Processing game_id: 2016020720
# Processing game_id: 2016020721
# Processing game_id: 2016020722
# Processing game_id: 2016020723
# Processing game_id: 2016020724
# Processing game_id: 2016020725
# Processing game_id: 2016020726
# Processing game_id: 2016020727
# Processing game_id: 2016020728
# Processing game_id: 2016020729
# Processing game_id: 2016020730
# Processing game_id: 2016020731
# Processing game_id: 2016020732
# Processing game_id: 2016020733
# Processing game_id: 2016020734
# Processing game_id: 2016020735
# Processing game_id: 2016020736
# Processing game_id: 2016020737
# Processing game_id: 2016020738
# Processing game_id: 2016020739
# Processing game_id: 2016020740
# Processing game_id: 2016020741
# Processing game_id: 2016020742
# Processing game_id: 2016020743
# Processing game_id: 2016020744
# Processing game_id: 2016020745
# Processing game_id: 2016020746
# Processing game_id: 2016020747
# Processing game_id: 2016020748
# Processing game_id: 2016020749
# Processing game_id: 2016020750
# Processing game_id: 2016020751
# Processing game_id: 2016020752
# Processing game_id: 2016020753
# Processing game_id: 2016020754
# Processing game_id: 2016020755
# Processing game_id: 2016020756
# Processing game_id: 2016020757
# Processing game_id: 2016020758
# Processing game_id: 2016020759
# Processing game_id: 2016020760
# Processing game_id: 2016020761
# Processing game_id: 2016020762
# Processing game_id: 2016020763
# Processing game_id: 2016020764
# Processing game_id: 2016020765
# Processing game_id: 2016020766
# Processing game_id: 2016020767
# Processing game_id: 2016020768
# Processing game_id: 2016020769
# Processing game_id: 2016020770
# Processing game_id: 2016020771
# Processing game_id: 2016020772
# Processing game_id: 2016020773
# Processing game_id: 2016020774
# Processing game_id: 2016020775
# Processing game_id: 2016020776
# Processing game_id: 2016020777
# Processing game_id: 2016020778
# Processing game_id: 2016020779
# Processing game_id: 2016020780
# Processing game_id: 2016020781
# Processing game_id: 2016020782
# Processing game_id: 2016020783
# Processing game_id: 2016020784
# Processing game_id: 2016020785
# Processing game_id: 2016020786
# Processing game_id: 2016020787
# Processing game_id: 2016020788
# Processing game_id: 2016020789
# Processing game_id: 2016020790
# Processing game_id: 2016020791
# Processing game_id: 2016020792
# Processing game_id: 2016020793
# Processing game_id: 2016020794
# Processing game_id: 2016020795
# Processing game_id: 2016020796
# Processing game_id: 2016020797
# Processing game_id: 2016020798
# Processing game_id: 2016020799
# Processing game_id: 2016020800
# Processing game_id: 2016020801
# Processing game_id: 2016020802
# Processing game_id: 2016020803
# Processing game_id: 2016020804
# Processing game_id: 2016020805
# Processing game_id: 2016020806
# Processing game_id: 2016020807
# Processing game_id: 2016020808
# Processing game_id: 2016020809
# Processing game_id: 2016020810
# Processing game_id: 2016020811
# Processing game_id: 2016020812
# Processing game_id: 2016020813
# Processing game_id: 2016020814
# Processing game_id: 2016020815
# Processing game_id: 2016020816
# Processing game_id: 2016020817
# Processing game_id: 2016020818
# Processing game_id: 2016020819
# Processing game_id: 2016020820
# Processing game_id: 2016020821
# Processing game_id: 2016020822
# Processing game_id: 2016020823
# Processing game_id: 2016020824
# Processing game_id: 2016020825
# Processing game_id: 2016020826
# Processing game_id: 2016020827
# Processing game_id: 2016020828
# Processing game_id: 2016020829
# Processing game_id: 2016020830
# Processing game_id: 2016020831
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = data_parser.get_shot_and_goal_pbp_df_for_season(2016)
#       2 df.sample(10)
#
# File c:\users\mega-pc\documents\github\ift6758-project\ift6758\data\nhl_data_parser.py:411, in NHLDataParser.get_shot_and_goal_pbp_df_for_season(self, season, with_regular_season, with_playoff_season)
#     409 try:
#     410     print(f"Processing game_id: {game_id}")
# --> 411     season_dfs.append(self.get_shot_and_goal_pbp_df(game_id))
#     412 except FileNotFoundError:
#     413     print(f"File not found for game_id: {game_id}, skipping.")
#
# File c:\users\mega-pc\documents\github\ift6758-project\ift6758\data\nhl_data_parser.py:297, in NHLDataParser.get_shot_and_goal_pbp_df(self, game_id)
#     294 shot_and_goal_plays = all_plays[all_plays['typeDescKey'].isin(RELEVANT_EVENT_TYPES)].copy()
#     295 shot_and_goal_plays['rebound'] = shot_and_goal_plays['previousEvent'].apply(lambda x: 1 if x == 'shot-on-goal' else 0)
# --> 297 shot_and_goal_plays['speed'] = shot_and_goal_plays.apply(
#     298     lambda row: row['distanceDiff'] / row['timeDiff']
#     299         if pd.notna(row['timeDiff']) and row['timeDiff'] > 0
#     300         else -1,
#     301     axis=1
#     302 )
#     304 mean_speed = shot_and_goal_plays[shot_and_goal_plays['speed'] != -1]['speed'].mean()
#     305 shot_and_goal_plays['speed'] = shot_and_goal_plays['speed'].replace(-1, mean_speed)
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\apply.py:905, in FrameApply.apply_series_generator(self)
#     902 results = {}
#     904 with option_context("mode.chained_assignment", None):
# --> 905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
#     907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\apply.py:1018, in FrameColumnApply.series_generator(self)
#    1016 @property
#    1017 def series_generator(self):
# -> 1018     values = self.values
#    1019     values = ensure_wrapped_if_datetimelike(values)
#    1020     assert len(values) > 0
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\apply.py:725, in FrameApply.values(self)
#     723 @cache_readonly
#     724 def values(self):
# --> 725     return self.obj.values
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\frame.py:11739, in DataFrame.values(self)
#   11666 """
#   11667 Return a Numpy representation of the DataFrame.
#   11668
#    (...)
#   11736        ['monkey', nan, None]], dtype=object)
#   11737 """
#   11738 self._consolidate_inplace()
# > 11739 return self._mgr.as_array()
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1770, in BlockManager.as_array(self, dtype, copy, na_value)
#    1768             arr = arr.astype(dtype, copy=False)
#    1769 else:
# -> 1770     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1771     # The underlying data was copied within _interleave
#    1772     copy = False
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1817, in BlockManager._interleave(self, dtype, na_value)
#    1815 for blk in self.blocks:
#    1816     rl = blk.mgr_locs
# -> 1817     arr = blk.get_values(dtype)
#    1818     result[rl.indexer] = arr
#    1819     itemmask[rl.indexer] = 1
#
# File c:\Users\Mega-PC\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1914, in NumpyBlock.get_values(self, dtype)
#    1912 def get_values(self, dtype: DtypeObj | None = None) -> np.ndarray:
#    1913     if dtype == _dtype_obj:
# -> 1914         return self.values.astype(_dtype_obj)
#    1915     return self.values
#
# KeyboardInterrupt:

# %% [markdown]
# And also a range of seasons:

# %%
df = data_parser.get_shot_and_goal_pbp_df_for_seasons(2016, 2018)
df.sample(10)
# Out:
#             gameId timeRemaining  periodNumber timeInPeriod  isGoal  shotType  \
# 250727  2018030183         06:03             3        13:57       1  backhand
# 252522  2018030311         17:15             1        02:45       0     wrist
# 143988  2017020987         05:53             1        14:07       0     wrist
# 140263  2017020930         08:13             2        11:47       0      snap
# 190010  2018020353         04:07             2        15:53       0     wrist
# 87643   2017020112         02:38             1        17:22       0     wrist
# 24955   2016020411         04:28             1        15:32       0      slap
# 194441  2018020424         17:11             3        02:49       1     wrist
# 22814   2016020375         03:39             3        16:21       0  backhand
# 236733  2018021095         18:06             1        01:54       0      snap
#
#         xCoord  yCoord    shootingTeam  shotDistance  shootingTeamSide  \
# 250727   -83.0     0.0  Golden Knights      6.000000                 1
# 252522   -31.0     5.0      Hurricanes     58.215118                 1
# 143988   -84.0    -8.0       Predators      9.433981                 1
# 140263    64.0   -19.0     Maple Leafs     31.400637                 0
# 190010   -81.0     5.0        Penguins      9.433981                 1
# 87643    -67.0    -3.0          Sabres     22.203603                 1
# 24955    -31.0   -15.0          Flyers     59.908263                 1
# 194441   -82.0     6.0  Golden Knights      9.219544                 1
# 22814    -75.0     3.0           Ducks     14.317821                 1
# 236733   -84.0     3.0           Stars      5.830952                 1
#
#              shootingPlayer        goalieInNet
# 250727           Mark Stone       Martin Jones
# 252522         Justin Faulk        Tuukka Rask
# 143988          Kyle Turris         Cam Talbot
# 140263       Connor Carrick     Jaroslav Halak
# 190010        Dominik Simon   Joonas Korpisalo
# 87643         Ryan O'Reilly     Anton Khudobin
# 24955   Shayne Gostisbehere      Kari Lehtonen
# 194441           Cody Eakin      Braden Holtby
# 22814           Corey Perry       Chad Johnson
# 236733    Alexander Radulov  Marc-Andre Fleury
