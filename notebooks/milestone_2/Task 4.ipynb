# %% [markdown]
# # Task 4 - Feature Engineering II

# %% [markdown]
# We will want to add even more features to achieve even more predictive power with our models.

# %%
from ift6758.data.nhl_data_parser import NHLDataParser
data_parser = NHLDataParser()

# %%
df = data_parser.get_shot_and_goal_pbp_df_for_season(2016)
df.head()
# Out:
#        gameId  timeRemaining  periodNumber timeInPeriod  isGoal shotType  \
# 0  2016020001           1129             1        01:11       0    wrist
# 1  2016020001           1027             1        02:53       0    wrist
# 2  2016020001            959             1        04:01       0    wrist
# 3  2016020001            914             1        04:46       0     slap
# 4  2016020001            794             1        06:46       0    wrist
#
#    emptyNet  xCoord  yCoord zoneCode  ... shotDistance  shotAngle  \
# 0         0   -77.0     5.0        O  ...         13.0  22.619865
# 1         0    86.0    13.0        O  ...    13.341664  77.005383
# 2         0    23.0   -38.0        N  ...    76.157731  29.931512
# 3         0    33.0   -15.0        O  ...    57.974132  14.995079
# 4         0   -34.0    28.0        O  ...    61.717096  26.980231
#
#   shootingTeamSide   shootingPlayer        goalieInNet previousEvent  \
# 0                1     Mitch Marner     Craig Anderson  blocked-shot
# 1                0      Chris Kelly  Frederik Andersen      giveaway
# 2                0        Cody Ceci  Frederik Andersen   missed-shot
# 3                0    Erik Karlsson  Frederik Andersen   missed-shot
# 4                1  Martin Marincin     Craig Anderson           hit
#
#   timeSincePreviousEvent  previousEventX  previousEventY  \
# 0                    1.0           -61.0            11.0
# 1                    5.0            54.0            -5.0
# 2                   18.0           -72.0             0.0
# 3                   19.0            77.0            -2.0
# 4                   16.0            47.0            34.0
#
#    distanceFromPreviousEvent
# 0                  17.088007
# 1                  36.715120
# 2                 102.318131
# 3                  45.880279
# 4                  81.221918
#
# [5 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# gameId                          0
# timeRemaining                   0
# periodNumber                    0
# timeInPeriod                    0
# isGoal                          0
# shotType                        0
# emptyNet                        0
# xCoord                          0
# yCoord                          0
# zoneCode                        0
# shootingTeam                    0
# shotDistance                    0
# shotAngle                       0
# shootingTeamSide                0
# shootingPlayer                  0
# goalieInNet                   314
# previousEvent                   1
# timeSincePreviousEvent          1
# previousEventX               4511
# previousEventY               4511
# distanceFromPreviousEvent    4511
# dtype: int64
