# %% [markdown]
# # Task 4 - Feature Engineering II

# %% [markdown]
# We will want to add even more features to achieve even more predictive power with our models.

# %%
from ift6758.data.nhl_data_parser import NHLDataParser
data_parser = NHLDataParser()

# %%
df = data_parser.get_shot_and_goal_pbp_df_for_season(2016)
df.head()
# Out:
#        gameId  timeRemaining  periodNumber timeInPeriod  isGoal shotType  \
# 0  2016020001           1129             1        01:11       0    wrist
# 1  2016020001           1027             1        02:53       0    wrist
# 2  2016020001            959             1        04:01       0    wrist
# 3  2016020001            914             1        04:46       0     slap
# 4  2016020001            794             1        06:46       0    wrist
#
#    emptyNet  xCoord  yCoord zoneCode  ...   shootingPlayer        goalieInNet  \
# 0         0   -77.0     5.0        O  ...     Mitch Marner     Craig Anderson
# 1         0    86.0    13.0        O  ...      Chris Kelly  Frederik Andersen
# 2         0    23.0   -38.0        N  ...        Cody Ceci  Frederik Andersen
# 3         0    33.0   -15.0        O  ...    Erik Karlsson  Frederik Andersen
# 4         0   -34.0    28.0        O  ...  Martin Marincin     Craig Anderson
#
#   previousEvent  timeDiff previousEventX previousEventY rebound  distanceDiff  \
# 0  blocked-shot       1.0          -61.0           11.0       0     17.088007
# 1      giveaway       5.0           54.0           -5.0       0     36.715120
# 2   missed-shot      18.0          -72.0            0.0       0    102.318131
# 3   missed-shot      19.0           77.0           -2.0       0     45.880279
# 4           hit      16.0           47.0           34.0       0     81.221918
#
#    shotAngleDiff      speed
# 0            0.0  17.088007
# 1            0.0   7.343024
# 2            0.0   5.684341
# 3            0.0   2.414752
# 4            0.0   5.076370
#
# [5 rows x 24 columns]

# %% [markdown]
# We should only have NaN in the previousEventX, previousEventY, distanceDiff, shotAngleDiff and speed columns.

# %%
df.isna().sum()
df[df['shotAngleDiff'] > 0.0]
# Out:
#            gameId  timeRemaining  periodNumber timeInPeriod  isGoal  shotType  \
# 10     2016020001            575             1        10:25       0      slap
# 11     2016020001            574             1        10:26       1  backhand
# 14     2016020001            431             1        12:49       1      slap
# 26     2016020001           1072             2        02:08       0  backhand
# 31     2016020001            681             2        08:39       0     wrist
# ...           ...            ...           ...          ...     ...       ...
# 80362  2016030416            720             2        08:00       0     wrist
# 80365  2016030416            574             2        10:26       0      snap
# 80369  2016030416            398             2        13:22       0     wrist
# 80378  2016030416            836             3        06:04       0      slap
# 80383  2016030416            598             3        10:02       0      slap
#
#        emptyNet  xCoord  yCoord zoneCode  ...    shootingPlayer  \
# 10            0    34.0   -25.0        O  ...     Erik Karlsson
# 11            0    82.0     3.0        O  ...        Bobby Ryan
# 14            0    34.0    -1.0        O  ...     Erik Karlsson
# 26            0   -87.0     8.0        O  ...        Mark Stone
# 31            0    45.0   -22.0        O  ...  William Nylander
# ...         ...     ...     ...      ...  ...               ...
# 80362         0    73.0    38.0        O  ...       Ron Hainsey
# 80365         0    56.0    15.0        O  ...       Phil Kessel
# 80369         0   -84.0   -25.0        O  ...  Viktor Arvidsson
# 80378         0    37.0    -1.0        O  ...    Mattias Ekholm
# 80383         0    43.0     1.0        O  ...    Mattias Ekholm
#
#              goalieInNet previousEvent  timeDiff previousEventX  \
# 10     Frederik Andersen  shot-on-goal       9.0           34.0
# 11     Frederik Andersen  shot-on-goal       1.0           34.0
# 14     Frederik Andersen  shot-on-goal       5.0           69.0
# 26     Frederik Andersen  shot-on-goal       6.0          -35.0
# 31        Craig Anderson  shot-on-goal       8.0           43.0
# ...                  ...           ...       ...            ...
# 80362        Pekka Rinne  shot-on-goal       7.0           81.0
# 80365        Pekka Rinne  shot-on-goal      11.0          -83.0
# 80369        Matt Murray  shot-on-goal      17.0          -65.0
# 80378        Matt Murray  shot-on-goal       5.0           84.0
# 80383        Matt Murray  shot-on-goal       0.0           71.0
#
#       previousEventY rebound  distanceDiff  shotAngleDiff      speed
# 10              20.0       1     45.000000       4.460848   5.000000
# 11             -25.0       1     55.569776       1.245364  55.569776
# 14              -8.0       1     35.693137      20.759783   7.138627
# 26             -19.0       1     58.591808      56.579241   9.765301
# 31              29.0       1     51.039201       5.663706   6.379900
# ...              ...     ...           ...            ...        ...
# 80362            7.0       1     32.015621      25.980421   4.573660
# 80365            6.0       1    139.291062      20.556045  12.662824
# 80369            5.0       1     35.510562      66.921779   2.088857
# 80378           21.0       1     51.894123      75.505796  10.378825
# 80383            1.0       1     28.000000       1.934466   7.357939
#
# [13457 rows x 24 columns]

# %%
df.shape[0]
# Out:
# 80389

# %% [markdown]
# If a single season has around 80000 shot/goal events, only about 4500 of these contain missing values for previous event coordinates. That's only 4500/80000 = 0.05625, so ~5.6% events. This is not insignificant, but isn't really a big concern either.
