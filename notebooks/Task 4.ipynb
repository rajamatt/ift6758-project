# %% [markdown]
# # Task 4 - Tidy Data
#
# For this task we want to tidy the raw JSON data we fetched from the NHL API. All we need to tidy the data into a clean DataFrame ready to be used for analysis is an instance of the `NHLDataParser` class.

# %%
from ift6758.data.nhl_data_parser import NHLDataParser

# %% [markdown]
# The `NHLDataParser` class has its own instance of the `NHLDataFetcher` class. If the game isn't found locally on the machine, it will fetch it and then tidy it. Here's a sample of using a specific game ID.

# %%
data_parser = NHLDataParser()
df = data_parser.get_shot_and_goal_pbp_df('2016020033')
df.sample(5) # displays 5 random shot/goal events
# Out:
#          gameId timeRemaining  periodNumber timeInPeriod  isGoal shotType  \
# 243  2016020033         11:55             3        08:05       0     snap
# 72   2016020033         02:52             1        17:08       0     snap
# 167  2016020033         07:14             2        12:46       0    wrist
# 79   2016020033         01:33             1        18:27       0    wrist
# 303  2016020033         00:23             3        19:37       0    wrist
#
#      xCoord  yCoord shootingTeam shotDistance  shootingTeamSide  \
# 243      69     -15       Sharks         25.0                 0
# 72       -8      -1      Rangers    81.006173                 1
# 167     -34      20       Sharks      58.5235                 1
# 79       17     -36       Sharks    80.498447                 0
# 303      66       1       Sharks    23.021729                 0
#
#       shootingPlayer   goalieInNet
# 243  Patrick Marleau  Antti Raanta
# 72     Ryan McDonagh  Martin Jones
# 167      Brent Burns  Antti Raanta
# 79       Brent Burns  Antti Raanta
# 303  Patrick Marleau  Antti Raanta

# %% [markdown]
# We can also use the `NHLDataParser` to get tidied shot and goal play-by-play for an entire season.

# %%
df = data_parser.get_shot_and_goal_pbp_df_for_season(2016)
df.sample(5)
# Out:
#            gameId timeRemaining  periodNumber timeInPeriod  isGoal shotType  \
# 74665  2016021225         01:39             3        18:21       0     snap
# 63014  2016021033         00:29             1        19:31       0     snap
# 6532   2016020109         18:45             3        01:15       0    wrist
# 34784  2016020573         01:54             1        18:06       0     slap
# 51888  2016020854         04:27             3        15:33       0    wrist
#
#        xCoord  yCoord shootingTeam  shotDistance  shootingTeamSide  \
# 74665   -38.0    18.0    Avalanche     54.083269                 1
# 63014   -76.0     8.0       Flyers     15.264338                 1
# 6532    -75.0    -3.0    Avalanche     14.317821                 1
# 34784    33.0    20.0      Rangers     59.464275                 0
# 51888   -84.0   -16.0        Kings     16.763055                 1
#
#             shootingPlayer         goalieInNet
# 74665  Francois Beauchemin          Jake Allen
# 63014       Brayden Schenn         Matt Murray
# 6532         Jarome Iginla  Michael Hutchinson
# 34784          Nick Holden         Steve Mason
# 51888          Jeff Carter          Mike Smith

# %% [markdown]
# And also a range of seasons:

# %%
df = data_parser.get_shot_and_goal_pbp_df_for_seasons(2016, 2018)
df.sample(5)
# Out:
#             gameId timeRemaining  periodNumber timeInPeriod  isGoal  shotType  \
# 41011   2016020677         03:11             3        16:49       0     wrist
# 33848   2016020557         04:47             2        15:13       0     wrist
# 131328  2017020793         18:22             1        01:38       0     wrist
# 167093  2017030323         18:20             3        01:40       0  backhand
# 239971  2018021146         15:56             1        04:04       0      slap
#
#         xCoord  yCoord shootingTeam  shotDistance  shootingTeamSide  \
# 41011     82.0    -2.0        Stars      7.280110                 0
# 33848     63.0     9.0      Canucks     27.513633                 0
# 131328     0.0    12.0     Senators     89.805345                 0
# 167093    82.0    -7.0         Jets      9.899495                 0
# 239971    72.0    14.0         Jets     22.022716                 0
#
#          shootingPlayer        goalieInNet
# 41011       Jiri Hudler      Thomas Greiss
# 33848   Nikita Tryamkin         Cam Talbot
# 131328  Mark Borowiecki          Alex Lyon
# 167093      Tyler Myers  Marc-Andre Fleury
# 239971   Dmitry Kulikov     Malcolm Subban
